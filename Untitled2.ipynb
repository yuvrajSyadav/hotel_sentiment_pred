# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("review1.csv")
data.head()
# Out:
#    Unnamed: 0                                             Review  Rating  \
# 0           0  nice hotel expensive parking got good deal sta...       4
# 1           1  ok nothing special charge diamond member hilto...       2
# 2           2  nice rooms not 4* experience hotel monaco seat...       3
# 3           3  unique, great stay, wonderful time hotel monac...       5
# 4           4  great stay great stay, went seahawk game aweso...       5
#
#                                                 text
# 0  nice hotel expens park got good deal stay hote...
# 1  ok noth special charg diamond member hilton de...
# 2  nice room not experi hotel monaco seattl good ...
# 3  uniqu great stay wonder time hotel monaco loca...
# 4  great stay great stay went seahawk game awesom...

# %%
from sklearn.feature_extraction.text import CountVectorizer
count = CountVectorizer(max_features = 5000 , ngram_range = (1,2))
x = count.fit_transform(data['text']).toarray()

# %%
import pickle
pickle.dump(count,open('cv1.pkl','wb'))

# %%
x.shape[1]
# Out:
# 5000

# %%
y = data['Rating']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x, y, test_size = 0.2 , random_state = 1)

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
model = nb.fit(x_train,y_train)

# %%
model.score(x_test,y_test)
# Out:
# 0.6008782629909734

# %%
pickle.dump(model,open('model1.pkl','wb'))

# %%
print(count.get_feature_names())
# Out:
# ['abl', 'abl check', 'abl walk', 'absolut', 'absolut beauti', 'absolut love', 'absolut wonder', 'abund', 'ac', 'accept', 'access', 'access room', 'accommod', 'accomod', 'accord', 'account', 'accur', 'acknowledg', 'act', 'action', 'activ', 'actual', 'ad', 'add', 'addit', 'address', 'adequ', 'adjac', 'adjoin', 'adjoin room', 'adjust', 'admit', 'adult', 'advanc', 'advantag', 'adventur', 'advertis', 'advic', 'advis', 'advisor', 'aerob', 'affect', 'affinia', 'afford', 'afraid', 'afternoon', 'afternoon tea', 'age', 'agenc', 'agent', 'aggress', 'ago', 'agre', 'agre review', 'ahead', 'ahead time', 'air', 'air condit', 'air condition', 'aircon', 'aircondit', 'airi', 'airlin', 'airport', 'airport bu', 'airport hotel', 'airport shuttl', 'al', 'ala', 'ala cart', 'alarm', 'alarm clock', 'albeit', 'alcatraz', 'alcohol', 'alley', 'alloc', 'allow', 'alot', 'alright', 'also', 'altern', 'although', 'amaz', 'amaz hotel', 'amaz view', 'amazingli', 'ambianc', 'ambienc', 'amen', 'america', 'american', 'ammen', 'ampl', 'amsterdam', 'angel', 'anim', 'anim team', 'ann', 'ann frank', 'anniversari', 'annoy', 'anoth', 'answer', 'answer question', 'ant', 'anticip', 'antiqu', 'anybodi', 'anymor', 'anytim', 'anyway', 'apart', 'apolog', 'appar', 'appeal', 'appear', 'appet', 'appl', 'appl vacat', 'appli', 'appoint', 'appreci', 'apprehens', 'approach', 'appropri', 'approx', 'approxim', 'april', 'aqua', 'aquarium', 'arc', 'arc triomph', 'architectur', 'area', 'area beach', 'area great', 'area hotel', 'area nice', 'area not', 'area room', 'argonaut', 'argu', 'arm', 'arno', 'around', 'arrang', 'arriv', 'arriv airport', 'arriv check', 'arriv earli', 'arriv hotel', 'arriv late', 'arriv pm', 'arriv resort', 'arriv room', 'art', 'asia', 'asian', 'asid', 'ask', 'ask better', 'ask desk', 'ask hotel', 'ask room', 'ask want', 'asleep', 'aspect', 'assign', 'assist', 'assort', 'assum', 'assur', 'ate', 'ate breakfast', 'ate restaur', 'atlant', 'atm', 'atmospher', 'atrium', 'attach', 'attempt', 'attend', 'attent', 'attent staff', 'attitud', 'attract', 'atv', 'au', 'audienc', 'aug', 'august', 'australia', 'authent', 'automat', 'avail', 'avail room', 'ave', 'aveda', 'avenu', 'averag', 'averag hotel', 'avoid', 'aw', 'await', 'awak', 'awar', 'away', 'away home', 'away hotel', 'away room', 'awesom', 'babi', 'back', 'background', 'bacon', 'bad', 'bad experi', 'bad hotel', 'bad not', 'bad review', 'bad thing', 'badli', 'bag', 'bagel', 'baggag', 'bahia', 'bahia princip', 'bahn', 'bake', 'bakeri', 'balconi', 'balconi overlook', 'balconi room', 'bali', 'balines', 'ball', 'bambu', 'banana', 'band', 'bang', 'bank', 'bar', 'bar area', 'bar beach', 'bar close', 'bar drink', 'bar good', 'bar great', 'bar hotel', 'bar lobbi', 'bar nice', 'bar not', 'bar open', 'bar pool', 'bar restaur', 'bar room', 'bar staff', 'barcelo', 'barcelona', 'barcelona hotel', 'bare', 'bargain', 'barrier', 'bart', 'bartend', 'barter', 'base', 'base explor', 'base review', 'basement', 'basi', 'basic', 'basket', 'bath', 'bath room', 'bath shower', 'bath suit', 'bathrob', 'bathroom', 'bathroom clean', 'bathroom door', 'bathroom floor', 'bathroom good', 'bathroom great', 'bathroom huge', 'bathroom larg', 'bathroom nice', 'bathroom not', 'bathroom room', 'bathroom shower', 'bathroom small', 'bathroom spaciou', 'bathtub', 'batteri', 'bavaro', 'bavaro beach', 'bavaro princess', 'bay', 'bb', 'bbq', 'beach', 'beach amaz', 'beach area', 'beach bar', 'beach beach', 'beach beauti', 'beach best', 'beach chair', 'beach clean', 'beach day', 'beach good', 'beach gorgeou', 'beach great', 'beach hotel', 'beach love', 'beach nice', 'beach not', 'beach pool', 'beach resort', 'beach restaur', 'beach room', 'beach towel', 'beach walk', 'bean', 'bear', 'beat', 'beat locat', 'beaten', 'beauti', 'beauti beach', 'beauti citi', 'beauti clean', 'beauti decor', 'beauti ground', 'beauti hotel', 'beauti place', 'beauti pool', 'beauti resort', 'beauti room', 'beauti staff', 'beauti view', 'bed', 'bed bathroom', 'bed breakfast', 'bed bug', 'bed c ...
# C:\Users\Admin\anaconda3\envs\hotel\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
